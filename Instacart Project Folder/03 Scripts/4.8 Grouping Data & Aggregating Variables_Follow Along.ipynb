# %% [markdown]
# ### **INDEX**
# 1. Setup Notebook
# 2. Following Along Exercse

# %% [markdown]
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .

# %% [markdown]
# ### **1. SETUP NOTEBOOK**

# %%
# import libraries
import pandas as pd
import numpy as np
import os
from pathlib import Path

# %%
# get the current working directory as a Path object
path = os.getcwd()

# update the path to parent folder
path = os.path.abspath(os.path.join(path, os.pardir))

# %%
# import orders products merged
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))

# %%
# create subset
df = df_ords_prods_merge [:1000000]

# %%
# check shape
df.shape
# Out:
# (1000000, 16)

# %%
# check columns
df.head()
# Out:
#    user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0        1             1                   2                  8
# 1        1             1                   2                  8
# 2        1             1                   2                  8
# 3        1             1                   2                  8
# 4        1             1                   2                  8
#
#    days_since_last_order  First_order  product_id  add_to_cart_order  \
# 0                    NaN         True         196                  1
# 1                    NaN         True       14084                  2
# 2                    NaN         True       12427                  3
# 3                    NaN         True       26088                  4
# 4                    NaN         True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# 0          0                                     Soda        77
# 1          0  Organic Unsweetened Vanilla Almond Milk        91
# 2          0                      Original Beef Jerky        23
# 3          0               Aged White Cheddar Popcorn        23
# 4          0         XL Pick-A-Size Paper Towel Rolls        54
#
#    department_id  prices _merge           busy_days busiest_period_of_day
# 0              7     9.0   both  Regularly busy day        Average orders
# 1             16    12.5   both  Regularly busy day        Average orders
# 2             19     4.4   both  Regularly busy day        Average orders
# 3             19     4.7   both  Regularly busy day        Average orders
# 4             17     1.0   both  Regularly busy day        Average orders

# %% [markdown]
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .

# %% [markdown]
# ### **2. FOLLOWING ALONG EXERCISE**

# %%
#create goup
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.800024   1  99
# 2                17.091743   1  98
# 3                17.913544   1  99
# 4                17.893092   1  99
# 5                15.214270   1  99
# 6                15.382135   1  99
# 7                17.694027   1  99
# 8                16.458105   1  91
# 9                15.957363   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.615061   1  99
# 13               16.484023   1  99
# 14               17.524632   1  99
# 15               15.691875   1  99
# 16               18.014071   1  99
# 17               16.150593   1  99
# 18               19.602850   1  99
# 19               17.631340   1  99
# 20               17.138607   1  99
# 21               21.956893   1  97

# %%
# create new column and aggregrate data
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform('max')

# %%
# confirm action
df_ords_prods_merge.head(15)
# Out:
#     user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0         1             1                   2                  8
# 1         1             1                   2                  8
# 2         1             1                   2                  8
# 3         1             1                   2                  8
# 4         1             1                   2                  8
# 5         1             2                   3                  7
# 6         1             2                   3                  7
# 7         1             2                   3                  7
# 8         1             2                   3                  7
# 9         1             2                   3                  7
# 10        1             2                   3                  7
# 11        1             3                   3                 12
# 12        1             3                   3                 12
# 13        1             3                   3                 12
# 14        1             3                   3                 12
#
#     days_since_last_order  First_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
# 5                    15.0        False         196                  1
# 6                    15.0        False       10258                  2
# 7                    15.0        False       12427                  3
# 8                    15.0        False       13176                  4
# 9                    15.0        False       26088                  5
# 10                   15.0        False       13032                  6
# 11                   21.0        False         196                  1
# 12                   21.0        False       12427                  2
# 13                   21.0        False       10258                  3
# 14                   21.0        False       25133                  4
#
#     reordered                             product_name  aisle_id  \
# 0           0                                     Soda        77
# 1           0  Organic Unsweetened Vanilla Almond Milk        91
# 2           0                      Original Beef Jerky        23
# 3           0               Aged White Cheddar Popcorn        23
# 4           0         XL Pick-A-Size Paper Towel Rolls        54
# 5           1                                     Soda        77
# 6           0                               Pistachios       117
# 7           1                      Original Beef Jerky        23
# 8           0                   Bag of Organic Bananas        24
# 9           1               Aged White Cheddar Popcorn        23
# 10          0                    Cinnamon Toast Crunch       121
# 11          1                                     Soda        77
# 12          1                      Original Beef Jerky        23
# 13          1                               Pistachios       117
# 14          0                    Organic String Cheese        21
#
#     department_id  prices _merge           busy_days busiest_period_of_day  \
# 0               7     9.0   both  Regularly busy day        Average orders
# 1              16    12.5   both  Regularly busy day        Average orders
# 2              19     4.4   both  Regularly busy day        Average orders
# 3              19     4.7   both  Regularly busy day        Average orders
# 4              17     1.0   both  Regularly busy day        Average orders
# 5               7     9.0   both     Least busy days        Average orders
# 6              19     3.0   both     Least busy days        Average orders
# 7              19     4.4   both     Least busy days        Average orders
# 8               4    10.3   both     Least busy days        Average orders
# 9              19     4.7   both     Least busy days        Average orders
# 10             14     4.0   both     Least busy days        Average orders
# 11              7     9.0   both     Least busy days         Fewest orders
# 12             19     4.4   both     Least busy days         Fewest orders
# 13             19     3.0   both     Least busy days         Fewest orders
# 14             16     8.6   both     Least busy days         Fewest orders
#
#     max_order
# 0          10
# 1          10
# 2          10
# 3          10
# 4          10
# 5          10
# 6          10
# 7          10
# 8          10
# 9          10
# 10         10
# 11         10
# 12         10
# 13         10
# 14         10

# %%
pd.options.display.max_rows = None

# %%
df_ords_prods_merge.head(100)
# Out:
#     user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0         1             1                   2                  8
# 1         1             1                   2                  8
# 2         1             1                   2                  8
# 3         1             1                   2                  8
# 4         1             1                   2                  8
# 5         1             2                   3                  7
# 6         1             2                   3                  7
# 7         1             2                   3                  7
# 8         1             2                   3                  7
# 9         1             2                   3                  7
# 10        1             2                   3                  7
# 11        1             3                   3                 12
# 12        1             3                   3                 12
# 13        1             3                   3                 12
# 14        1             3                   3                 12
# 15        1             3                   3                 12
# 16        1             4                   4                  7
# 17        1             4                   4                  7
# 18        1             4                   4                  7
# 19        1             4                   4                  7
# 20        1             4                   4                  7
# 21        1             5                   4                 15
# 22        1             5                   4                 15
# 23        1             5                   4                 15
# 24        1             5                   4                 15
# 25        1             5                   4                 15
# 26        1             5                   4                 15
# 27        1             5                   4                 15
# 28        1             5                   4                 15
# 29        1             6                   2                  7
# 30        1             6                   2                  7
# 31        1             6                   2                  7
# 32        1             6                   2                  7
# 33        1             7                   1                  9
# 34        1             7                   1                  9
# 35        1             7                   1                  9
# 36        1             7                   1                  9
# 37        1             7                   1                  9
# 38        1             8                   1                 14
# 39        1             8                   1                 14
# 40        1             8                   1                 14
# 41        1             8                   1                 14
# 42        1             8                   1                 14
# 43        1             8                   1                 14
# 44        1             9                   1                 16
# 45        1             9                   1                 16
# 46        1             9                   1                 16
# 47        1             9                   1                 16
# 48        1             9                   1                 16
# 49        1             9                   1                 16
# 50        1            10                   4                  8
# 51        1            10                   4                  8
# 52        1            10                   4                  8
# 53        1            10                   4                  8
# 54        1            10                   4                  8
# 55        1            10                   4                  8
# 56        1            10                   4                  8
# 57        1            10                   4                  8
# 58        1            10                   4                  8
# 59        2             1                   2                 11
# 60        2             1                   2                 11
# 61        2             1                   2                 11
# 62        2             1                   2                 11
# 63        2             1                   2                 11
# 64        2             1                   2                 11
# 65        2             1                   2                 11
# 66        2             1                   2                 11
# 67        2             1                   2                 11
# 68        2             1                   2                 11
# 69        2             1                   2                 11
# 70        2             1                   2                 11
# 71        2             1                   2                 11
# 72        2             2                   5                 10
# 73        2             2                   5                 10
# 74        2             2                   5                 10
# 75        2             2                   5                 10
# 76        2             2                   5                 10
# 77        2             2                   5                 10
# 78        2             3                   1                 10
# 79        2             3                   1                 10
# 80        2             3                   1                 10
# 81        2             3                   1                 10
# 82        2             3                   1                 10
# 83        2             4                   2                 10
# 84        2             4                   2                 10
# 85        2             4                   2                 10
# 86        2             4                   2                 10
# 87        2             4                   2                 10
# 88        2             4                   2                 10
# 89        2             4                   2                 10
# 90        2             4                   2                 10
# 91        2             4                   2                 10
# 92        2             4                   2                 10
# 93        2             4                   2                 10
# 94        2             4                   2                 10
# 95        2             4                   2                 10
# 96        2             5                   3                 11
# 97        2             5                   3                 11
# 98        2             5                   3                 11
# 99        2             5                   3                 11
#
#     days_since_last_order  First_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
# 5                    15.0        False         196                  1
# 6                    15.0        False       10258                  2
# 7                    15.0        False       12427                  3
# 8                    15.0        False       13176                  4
# 9                    15.0        False       26088                  5
# 10                   15.0        False       13032                  6
# 11                   21.0        False         196                  1
# 12                   21.0        False       12427                  2
# 13                   21.0        False       10258                  3
# 14                   21.0        False       25133                  4
# 15                   21.0        False       30450                  5
# 16                   29.0        False         196                  1
# 17                   29.0        False       12427                  2
# 18                   29.0        False       10258                  3
# 19                   29.0        False       25133                  4
# 20                   29.0        False       26405                  5
# 21                   28.0        False         196                  1
# 22                   28.0        False       12427                  2
# 23                   28.0        False       10258                  3
# 24                   28.0        False       25133                  4
# 25                   28.0        False       10326                  5
# 26                   28.0        False       17122                  6
# 27                   28.0        False       41787                  7
# 28                   28.0        False       13176                  8
# 29                   19.0        False         196                  1
# 30                   19.0        False       12427                  2
# 31                   19.0        False       10258                  3
# 32                   19.0        False       25133                  4
# 33                   20.0        False         196                  1
# 34                   20.0        False       10258                  2
# 35                   20.0        False       12427                  3
# 36                   20.0        False       25133                  4
# 37                   20.0        False       13032                  5
# 38                   14.0        False       12427                  1
# 39                   14.0        False         196                  2
# 40                   14.0        False       10258                  3
# 41                   14.0        False       25133                  4
# 42                   14.0        False       46149                  5
# 43                   14.0        False       49235                  6
# 44                    0.0        False       49235                  1
# 45                    0.0        False       46149                  2
# 46                    0.0        False       25133                  3
# 47                    0.0        False         196                  4
# 48                    0.0        False       10258                  5
# 49                    0.0        False       12427                  6
# 50                   30.0        False         196                  1
# 51                   30.0        False       46149                  2
# 52                   30.0        False       39657                  3
# 53                   30.0        False       38928                  4
# 54                   30.0        False       25133                  5
# 55                   30.0        False       10258                  6
# 56                   30.0        False       35951                  7
# 57                   30.0        False       13032                  8
# 58                   30.0        False       12427                  9
# 59                    NaN         True       32792                  1
# 60                    NaN         True       47766                  2
# 61                    NaN         True       20574                  3
# 62                    NaN         True       12000                  4
# 63                    NaN         True       48110                  5
# 64                    NaN         True       22474                  6
# 65                    NaN         True       16589                  7
# 66                    NaN         True       35917                  8
# 67                    NaN         True       27344                  9
# 68                    NaN         True       30489                 10
# 69                    NaN         True       27966                 11
# 70                    NaN         True       13176                 12
# 71                    NaN         True       45066                 13
# 72                   10.0        False       16797                  1
# 73                   10.0        False       47526                  2
# 74                   10.0        False        8479                  3
# 75                   10.0        False       47766                  4
# 76                   10.0        False       19051                  5
# 77                   10.0        False        8138                  6
# 78                    3.0        False       47766                  1
# 79                    3.0        False       32792                  2
# 80                    3.0        False       20574                  3
# 81                    3.0        False        7781                  4
# 82                    3.0        False       28874                  5
# 83                    8.0        False       49451                  1
# 84                    8.0        False       32792                  2
# 85                    8.0        False       32139                  3
# 86                    8.0        False       34688                  4
# 87                    8.0        False       36735                  5
# 88                    8.0        False       37646                  6
# 89                    8.0        False       22829                  7
# 90                    8.0        False       24852                  8
# 91                    8.0        False       47209                  9
# 92                    8.0        False       33276                 10
# 93                    8.0        False       45613                 11
# 94                    8.0        False        9681                 12
# 95                    8.0        False       21150                 13
# 96                    8.0        False       47144                  1
# 97                    8.0        False        5322                  2
# 98                    8.0        False       17224                  3
# 99                    8.0        False       38656                  4
#
#     reordered                                       product_name  aisle_id  \
# 0           0                                               Soda        77
# 1           0            Organic Unsweetened Vanilla Almond Milk        91
# 2           0                                Original Beef Jerky        23
# 3           0                         Aged White Cheddar Popcorn        23
# 4           0                   XL Pick-A-Size Paper Towel Rolls        54
# 5           1                                               Soda        77
# 6           0                                         Pistachios       117
# 7           1                                Original Beef Jerky        23
# 8           0                             Bag of Organic Bananas        24
# 9           1                         Aged White Cheddar Popcorn        23
# 10          0                              Cinnamon Toast Crunch       121
# 11          1                                               Soda        77
# 12          1                                Original Beef Jerky        23
# 13          1                                         Pistachios       117
# 14          0                              Organic String Cheese        21
# 15          0                               Creamy Almond Butter        88
# 16          1                                               Soda        77
# 17          1                                Original Beef Jerky        23
# 18          1                                         Pistachios       117
# 19          1                              Organic String Cheese        21
# 20          1                   XL Pick-A-Size Paper Towel Rolls        54
# 21          1                                               Soda        77
# 22          1                                Original Beef Jerky        23
# 23          1                                         Pistachios       117
# 24          1                              Organic String Cheese        21
# 25          0                                Organic Fuji Apples        24
# 26          0                                  Honeycrisp Apples        24
# 27          0                                     Bartlett Pears        24
# 28          1                             Bag of Organic Bananas        24
# 29          1                                               Soda        77
# 30          1                                Original Beef Jerky        23
# 31          1                                         Pistachios       117
# 32          1                              Organic String Cheese        21
# 33          1                                               Soda        77
# 34          1                                         Pistachios       117
# 35          1                                Original Beef Jerky        23
# 36          1                              Organic String Cheese        21
# 37          1                              Cinnamon Toast Crunch       121
# 38          1                                Original Beef Jerky        23
# 39          1                                               Soda        77
# 40          1                                         Pistachios       117
# 41          1                              Organic String Cheese        21
# 42          0                                  Zero Calorie Cola        77
# 43          0                                Organic Half & Half        53
# 44          1                                Organic Half & Half        53
# 45          1                                  Zero Calorie Cola        77
# 46          1                              Organic String Cheese        21
# 47          1                                               Soda        77
# 48          1                                         Pistachios       117
# 49          1                                Original Beef Jerky        23
# 50          1                                               Soda        77
# 51          1                                  Zero Calorie Cola        77
# 52          0                             Milk Chocolate Almonds        45
# 53          0                           0% Greek Strained Yogurt       120
# 54          1                              Organic String Cheese        21
# 55          1                                         Pistachios       117
# 56          0                    Organic Unsweetened Almond Milk        91
# 57          1                              Cinnamon Toast Crunch       121
# 58          1                                Original Beef Jerky        23
# 59          0                     Chipotle Beef & Pork Realstick        23
# 60          0                                    Organic Avocado        24
# 61          0                                     Roasted Turkey        96
# 62          0           Baked Organic Sea Salt Crunchy Pea Snack        72
# 63          0            Thin Stackers Brown Rice Lightly Salted        78
# 64          0                     Cheddar Bunnies Snack Crackers        78
# 65          0                                     Plantain Chips       107
# 66          0                   Organic Just Concord Grape Juice        98
# 67          0                               Uncured Genoa Salami        96
# 68          0                                    Original Hummus        67
# 69          0                                Organic Raspberries       123
# 70          0                             Bag of Organic Bananas        24
# 71          0                                   Honeycrisp Apple        24
# 72          0                                       Strawberries        24
# 73          0                                    Goat Cheese Log        21
# 74          0              Original Black Box Tablewater Cracker        78
# 75          1                                    Organic Avocado        24
# 76          0               Pita Chips, Simply Naked, Party Size       107
# 77          0                                 Traditional Hummus        67
# 78          1                                    Organic Avocado        24
# 79          1                     Chipotle Beef & Pork Realstick        23
# 80          1                                     Roasted Turkey        96
# 81          0  Organic Sticks Low Moisture Part Skim Mozzarel...        21
# 82          0                                 Carrot Ginger Soup         1
# 83          0                              Artichoke Spinach Dip        67
# 84          1                     Chipotle Beef & Pork Realstick        23
# 85          0                            Hommus Classic Original        67
# 86          0  Good Belly Probiotics Juice Drink Blueberry Ac...        31
# 87          0              Organic Roasted Sliced Chicken Breast        96
# 88          0                                Organic Gala Apples        24
# 89          0          Multigrain Flax Seeded Flatbread Crackers        78
# 90          0                                             Banana        24
# 91          0                               Organic Hass Avocado        24
# 92          0                              Kalamata Olive Spread        67
# 93          0                                           Pad Thai        38
# 94          0  Chicken Tikka Masala with Cumin Infused Basmat...        38
# 95          0                            Fire Grilled Steak Bowl        38
# 96          0     Unsweetened Original Almond Breeze Almond Milk        91
# 97          0  Gluten Free Dark Chocolate Chunk Chewy with a ...         3
# 98          0                   Oats & Honey Gluten Free Granola         3
# 99          0  Gluten Free Peanut Butter Dark Chocolate Chewy...         3
#
#     department_id  prices _merge           busy_days busiest_period_of_day  \
# 0               7     9.0   both  Regularly busy day        Average orders
# 1              16    12.5   both  Regularly busy day        Average orders
# 2              19     4.4   both  Regularly busy day        Average orders
# 3              19     4.7   both  Regularly busy day        Average orders
# 4              17     1.0   both  Regularly busy day        Average orders
# 5               7     9.0   both     Least busy days        Average orders
# 6              19     3.0   both     Least busy days        Average orders
# 7              19     4.4   both     Least busy days        Average orders
# 8               4    10.3   both     Least busy days        Average orders
# 9              19     4.7   both     Least busy days        Average orders
# 10             14     4.0   both     Least busy days        Average orders
# 11              7     9.0   both     Least busy days         Fewest orders
# 12             19     4.4   both     Least busy days         Fewest orders
# 13             19     3.0   both     Least busy days         Fewest orders
# 14             16     8.6   both     Least busy days         Fewest orders
# 15             13     3.2   both     Least busy days         Fewest orders
# 16              7     9.0   both     Least busy days        Average orders
# 17             19     4.4   both     Least busy days        Average orders
# 18             19     3.0   both     Least busy days        Average orders
# 19             16     8.6   both     Least busy days        Average orders
# 20             17     1.0   both     Least busy days        Average orders
# 21              7     9.0   both     Least busy days         Fewest orders
# 22             19     4.4   both     Least busy days         Fewest orders
# 23             19     3.0   both     Least busy days         Fewest orders
# 24             16     8.6   both     Least busy days         Fewest orders
# 25              4     2.7   both     Least busy days         Fewest orders
# 26              4    14.0   both     Least busy days         Fewest orders
# 27              4     5.0   both     Least busy days         Fewest orders
# 28              4    10.3   both     Least busy days         Fewest orders
# 29              7     9.0   both  Regularly busy day        Average orders
# 30             19     4.4   both  Regularly busy day        Average orders
# 31             19     3.0   both  Regularly busy day        Average orders
# 32             16     8.6   both  Regularly busy day        Average orders
# 33              7     9.0   both        Busiest days         Fewest orders
# 34             19     3.0   both        Busiest days         Fewest orders
# 35             19     4.4   both        Busiest days         Fewest orders
# 36             16     8.6   both        Busiest days         Fewest orders
# 37             14     4.0   both        Busiest days         Fewest orders
# 38             19     4.4   both        Busiest days         Fewest orders
# 39              7     9.0   both        Busiest days         Fewest orders
# 40             19     3.0   both        Busiest days         Fewest orders
# 41             16     8.6   both        Busiest days         Fewest orders
# 42              7    13.4   both        Busiest days         Fewest orders
# 43             16     1.8   both        Busiest days         Fewest orders
# 44             16     1.8   both        Busiest days         Fewest orders
# 45              7    13.4   both        Busiest days         Fewest orders
# 46             16     8.6   both        Busiest days         Fewest orders
# 47              7     9.0   both        Busiest days         Fewest orders
# 48             19     3.0   both        Busiest days         Fewest orders
# 49             19     4.4   both        Busiest days         Fewest orders
# 50              7     9.0   both     Least busy days        Average orders
# 51              7    13.4   both     Least busy days        Average orders
# 52             19     6.8   both     Least busy days        Average orders
# 53             16    12.6   both     Least busy days        Average orders
# 54             16     8.6   both     Least busy days        Average orders
# 55             19     3.0   both     Least busy days        Average orders
# 56             16     1.3   both     Least busy days        Average orders
# 57             14     4.0   both     Least busy days        Average orders
# 58             19     4.4   both     Least busy days        Average orders
# 59             19     5.2   both  Regularly busy day         Fewest orders
# 60              4     6.3   both  Regularly busy day         Fewest orders
# 61             20     2.3   both  Regularly busy day         Fewest orders
# 62             13    10.9   both  Regularly busy day         Fewest orders
# 63             19     2.7   both  Regularly busy day         Fewest orders
# 64             19     4.1   both  Regularly busy day         Fewest orders
# 65             19     5.0   both  Regularly busy day         Fewest orders
# 66              7     9.4   both  Regularly busy day         Fewest orders
# 67             20    14.8   both  Regularly busy day         Fewest orders
# 68             20     7.5   both  Regularly busy day         Fewest orders
# 69              4     4.4   both  Regularly busy day         Fewest orders
# 70              4    10.3   both  Regularly busy day         Fewest orders
# 71              4     2.5   both  Regularly busy day         Fewest orders
# 72              4     1.3   both  Regularly busy day         Fewest orders
# 73             16     2.0   both  Regularly busy day         Fewest orders
# 74             19     3.5   both  Regularly busy day         Fewest orders
# 75              4     6.3   both  Regularly busy day         Fewest orders
# 76             19     3.9   both  Regularly busy day         Fewest orders
# 77             20     2.0   both  Regularly busy day         Fewest orders
# 78              4     6.3   both        Busiest days         Fewest orders
# 79             19     5.2   both        Busiest days         Fewest orders
# 80             20     2.3   both        Busiest days         Fewest orders
# 81             16     6.6   both        Busiest days         Fewest orders
# 82             20     6.2   both        Busiest days         Fewest orders
# 83             20     7.1   both  Regularly busy day         Fewest orders
# 84             19     5.2   both  Regularly busy day         Fewest orders
# 85             20     7.5   both  Regularly busy day         Fewest orders
# 86              7     5.8   both  Regularly busy day         Fewest orders
# 87             20     8.9   both  Regularly busy day         Fewest orders
# 88              4     9.1   both  Regularly busy day         Fewest orders
# 89             19     5.5   both  Regularly busy day         Fewest orders
# 90              4    12.3   both  Regularly busy day         Fewest orders
# 91              4     4.0   both  Regularly busy day         Fewest orders
# 92             20    10.8   both  Regularly busy day         Fewest orders
# 93              1    12.6   both  Regularly busy day         Fewest orders
# 94              1     2.0   both  Regularly busy day         Fewest orders
# 95              1     5.9   both  Regularly busy day         Fewest orders
# 96             16    14.0   both     Least busy days         Fewest orders
# 97             19     2.9   both     Least busy days         Fewest orders
# 98             19     1.6   both     Least busy days         Fewest orders
# 99             19     3.4   both     Least busy days         Fewest orders
#
#     max_order
# 0          10
# 1          10
# 2          10
# 3          10
# 4          10
# 5          10
# 6          10
# 7          10
# 8          10
# 9          10
# 10         10
# 11         10
# 12         10
# 13         10
# 14         10
# 15         10
# 16         10
# 17         10
# 18         10
# 19         10
# 20         10
# 21         10
# 22         10
# 23         10
# 24         10
# 25         10
# 26         10
# 27         10
# 28         10
# 29         10
# 30         10
# 31         10
# 32         10
# 33         10
# 34         10
# 35         10
# 36         10
# 37         10
# 38         10
# 39         10
# 40         10
# 41         10
# 42         10
# 43         10
# 44         10
# 45         10
# 46         10
# 47         10
# 48         10
# 49         10
# 50         10
# 51         10
# 52         10
# 53         10
# 54         10
# 55         10
# 56         10
# 57         10
# 58         10
# 59         14
# 60         14
# 61         14
# 62         14
# 63         14
# 64         14
# 65         14
# 66         14
# 67         14
# 68         14
# 69         14
# 70         14
# 71         14
# 72         14
# 73         14
# 74         14
# 75         14
# 76         14
# 77         14
# 78         14
# 79         14
# 80         14
# 81         14
# 82         14
# 83         14
# 84         14
# 85         14
# 86         14
# 87         14
# 88         14
# 89         14
# 90         14
# 91         14
# 92         14
# 93         14
# 94         14
# 95         14
# 96         14
# 97         14
# 98         14
# 99         14

# %%
# create and set flag
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_ords_prods_merge['loyalty_flag'].value_counts(dropna=False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# 20        1      New customer             4
# 21        1      New customer             5
# 22        1      New customer             5
# 23        1      New customer             5
# 24        1      New customer             5
# 25        1      New customer             5
# 26        1      New customer             5
# 27        1      New customer             5
# 28        1      New customer             5
# 29        1      New customer             6
# 30        1      New customer             6
# 31        1      New customer             6
# 32        1      New customer             6
# 33        1      New customer             7
# 34        1      New customer             7
# 35        1      New customer             7
# 36        1      New customer             7
# 37        1      New customer             7
# 38        1      New customer             8
# 39        1      New customer             8
# 40        1      New customer             8
# 41        1      New customer             8
# 42        1      New customer             8
# 43        1      New customer             8
# 44        1      New customer             9
# 45        1      New customer             9
# 46        1      New customer             9
# 47        1      New customer             9
# 48        1      New customer             9
# 49        1      New customer             9
# 50        1      New customer            10
# 51        1      New customer            10
# 52        1      New customer            10
# 53        1      New customer            10
# 54        1      New customer            10
# 55        1      New customer            10
# 56        1      New customer            10
# 57        1      New customer            10
# 58        1      New customer            10
# 59        2  Regular customer             1
